# %% [markdown]
# <a href="https://colab.research.google.com/github/Jadrianp29/testreko/blob/main/DS_C2_SC2_JesusAdrianAguilarPerez_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ¨Extraer informacion¨

# %%
country = pd.read_csv('/content/country_vaccinations.csv')

# %% [markdown]
# Mostrar estructura y tipo de datos

# %%
country['date'] = pd.to_datetime(country['date'])

# %%
country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              3081 non-null   object
#  1   iso_code                             2833 non-null   object
#  2   date                                 3081 non-null   datetime64[ns]
#  3   total_vaccinations                   1980 non-null   float64
#  4   people_vaccinated                    1643 non-null   float64
#  5   people_fully_vaccinated              1016 non-null   float64
#  6   daily_vaccinations_raw               1642 non-null   float64
#  7   daily_vaccinations                   2960 non-null   float64
#  8   total_vaccinations_per_hundred       1980 non-null   float64
#  9   people_vaccinated_per_hundred        1643 non-null   float64
#  10  people_fully_vaccinated_per_hundred  1016 non-null   float64
# ...

# %% [markdown]
# ¨cambiando date a tipo datetime64¨

# %%
country.head()
country.tail()
country.sample(10)
# Out:
#                country iso_code       date  total_vaccinations  \
# 1775            Mexico      MEX 2020-12-26                 NaN
# 671            Croatia      HRV 2021-01-23                 NaN
# 2779       Switzerland      CHE 2021-01-22                 NaN
# 2331            Russia      RUS 2021-01-15                 NaN
# 2103            Panama      PAN 2021-01-30              8772.0
# 425             Canada      CAN 2021-01-27            890536.0
# 350             Brazil      BRA 2021-02-07           3553681.0
# 953            Estonia      EST 2021-02-10             58261.0
# 272            Belgium      BEL 2021-02-03            380974.0
# 1944  Northern Ireland      NaN 2020-12-30                 NaN
#
#       people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 1775                NaN                      NaN                     NaN
# 671                 NaN                      NaN                     NaN
# ...

# %% [markdown]
# ¨Determinar la cantidad de vacunas aplicadas de cada compañía (con base en cómo lo reporta cada país en la columna vaccines)¨

# %%
country[['iso_code','vaccines']].groupby('iso_code').sum()
# Out:
#                                                    vaccines
# iso_code
# AIA       Oxford/AstraZenecaOxford/AstraZenecaOxford/Ast...
# ALB       Pfizer/BioNTechPfizer/BioNTechPfizer/BioNTechP...
# AND       Pfizer/BioNTechPfizer/BioNTechPfizer/BioNTechP...
# ARE       Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# ARG       Sputnik VSputnik VSputnik VSputnik VSputnik VS...
# ...                                                     ...
# SWE       Oxford/AstraZeneca, Pfizer/BioNTechOxford/Astr...
# SYC       Oxford/AstraZeneca, Sinopharm/BeijingOxford/As...
# TCA       Pfizer/BioNTechPfizer/BioNTechPfizer/BioNTechP...
# TUR       SinovacSinovacSinovacSinovacSinovacSinovacSino...
# USA       Moderna, Pfizer/BioNTechModerna, Pfizer/BioNTe...
#
# [86 rows x 1 columns]

# %% [markdown]
# d. Obtener la cantidad de vacunas aplicadas en todo el mundo.

# %%
country['total_vaccinations'].sum()
# Out:
# 2602242783.0

# %% [markdown]
# e. Calcular el promedio de vacunas aplicadas por país.

# %%
country[['iso_code', 'daily_vaccinations']].groupby('iso_code').mean()
# Out:
#           daily_vaccinations
# iso_code
# AIA               149.000000
# ALB                44.625000
# AND                51.750000
# ARE            101290.384615
# ARG             12705.630435
# ...                      ...
# SWE              8494.382979
# SYC              1363.575758
# TCA               222.000000
# TUR            119377.935484
# USA            820716.618182
#
# [86 rows x 1 columns]

# %% [markdown]
# f. Determinar la cantidad de vacunas aplicadas el día 29/01/21 en todo el mundo.

# %%
fecha= country.loc[country['date'] == '2021-01-29', ['total_vaccinations']]
fecha['total_vaccinations'].sum()
# Out:
# 74388085.0

# %% [markdown]
# Crear un dataframe nuevo denominado conDiferencias que contenga los datos originales y una columna derivada (diferencias) con las diferencias de aplicación entre las columnas daily_vaccionations y daily_vaccionations_raw.

# %%
conDiferencias = country
conDiferencias['diferencias'] = conDiferencias['daily_vaccinations'] - conDiferencias['daily_vaccinations_raw']
conDiferencias
# Out:
#       country iso_code        date  total_vaccinations  people_vaccinated  \
# 0     Albania      ALB  2021-01-10                 0.0                0.0
# 1     Albania      ALB  2021-01-11                 NaN                NaN
# 2     Albania      ALB  2021-01-12               128.0              128.0
# 3     Albania      ALB  2021-01-13               188.0              188.0
# 4     Albania      ALB  2021-01-14               266.0              266.0
# ...       ...      ...         ...                 ...                ...
# 3076    Wales      NaN  2021-02-08            632251.0           628760.0
# 3077    Wales      NaN  2021-02-09            659106.0           655419.0
# 3078    Wales      NaN  2021-02-10            687892.0           684097.0
# 3079    Wales      NaN  2021-02-11            719954.0           715944.0
# 3080    Wales      NaN  2021-02-12            753669.0           749445.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %% [markdown]
# h. Obtener el período de tiempo entre el registro con fecha más reciente y el registro con fecha más antigua.

# %%
print(country['date'].max()-country['date'].min())
# Out:
# 62 days 00:00:00

# %% [markdown]
# i. Crear un dataframe nuevo denominado conCantidad que contenga los datos originales y una columna derivada (canVac) con la cantidad de vacunas utilizadas cada día (usar la columna vaccines y separar por el carácter /).

# %%
conCantidad = country
conCantidad['CanVac'] = conCantidad['vaccines'].str.split(',').str.len()
conCantidad
# Out:
#       country iso_code        date  total_vaccinations  people_vaccinated  \
# 0     Albania      ALB  2021-01-10                 0.0                0.0
# 1     Albania      ALB  2021-01-11                 NaN                NaN
# 2     Albania      ALB  2021-01-12               128.0              128.0
# 3     Albania      ALB  2021-01-13               188.0              188.0
# 4     Albania      ALB  2021-01-14               266.0              266.0
# ...       ...      ...         ...                 ...                ...
# 3076    Wales      NaN  2021-02-08            632251.0           628760.0
# 3077    Wales      NaN  2021-02-09            659106.0           655419.0
# 3078    Wales      NaN  2021-02-10            687892.0           684097.0
# 3079    Wales      NaN  2021-02-11            719954.0           715944.0
# 3080    Wales      NaN  2021-02-12            753669.0           749445.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %% [markdown]
# j. Generar un dataframe denominado antes20 con todos los registros que se hayan realizado antes del 20 de diciembre de 2020.

# %%
antes20 = country[country['date']<'2020-12-20']
antes20
# Out:
#                country iso_code        date  total_vaccinations  \
# 406             Canada      CAN  2020-12-19                 NaN
# 543              China      CHN  2020-12-15           1500000.0
# 544              China      CHN  2020-12-16                 NaN
# 545              China      CHN  2020-12-17                 NaN
# 546              China      CHN  2020-12-18                 NaN
# 547              China      CHN  2020-12-19                 NaN
# 847            England      NaN  2020-12-13             55389.0
# 848            England      NaN  2020-12-14                 NaN
# 849            England      NaN  2020-12-15                 NaN
# 850            England      NaN  2020-12-16                 NaN
# 851            England      NaN  2020-12-17                 NaN
# 852            England      NaN  2020-12-18                 NaN
# 853            England      NaN  2020-12-19                 NaN
# 1432            Israel      ISR  2020-12-19                58.0
# ...

# %% [markdown]
# k. Obtener un dataframe denominado pfizer con todos los registros donde se haya utilizado la vacuna Pfizer.

# %%
pfizer = country
pfizer['CanVac'] = pfizer['vaccines'].str.split(',')
pfizer['CanVac']
# Out:
# 0                            [Pfizer/BioNTech]
# 1                            [Pfizer/BioNTech]
# 2                            [Pfizer/BioNTech]
# 3                            [Pfizer/BioNTech]
# 4                            [Pfizer/BioNTech]
#                          ...
# 3076    [Oxford/AstraZeneca,  Pfizer/BioNTech]
# 3077    [Oxford/AstraZeneca,  Pfizer/BioNTech]
# 3078    [Oxford/AstraZeneca,  Pfizer/BioNTech]
# 3079    [Oxford/AstraZeneca,  Pfizer/BioNTech]
# 3080    [Oxford/AstraZeneca,  Pfizer/BioNTech]
# Name: CanVac, Length: 3081, dtype: object

# %% [markdown]
# l. Almacenar los dataframes generados (conDiferencias, conCantidad, antes20 y pfizer) en un archivo de Excel denominado resultadosReto.xlsx, donde cada dataframe ocupe una hoja diferente. Se recomienda ver la documentación de pd.ExcelWriter.

# %%
with pd.ExcelWriter("Dateframefinal.xlsx") as writer:
    conDiferencias.to_excel(writer, sheet_name="Sheet1")  
    conCantidad.to_excel(writer, sheet_name="Sheet2") 
    antes20.to_excel(writer, sheet_name="Sheet3")
    pfizer.to_excel(writer, sheet_name="Sheet4")

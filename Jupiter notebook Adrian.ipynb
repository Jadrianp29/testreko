# %% [markdown]
# # "My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
# ## __Adrian Aguilar__
# Data scientist

# %% [markdown]
# ## _Im interested in data science because is the sexiest job fof the milenia_

# %% [markdown]
# ### These code must print hello world

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# from IPython.display Import YoutubeVideo
# Youtubevideo(´RBSGK1AVoIM´; Width= 800, height = 500)
#  - (1,2,3,4,5) -
# 1. This
# 2. is
# 3. a
# 4. Numberd list
#     1.sub text
#     2.sub text
#       1. sub sub text
#       2. sub sub text
# 5. List
